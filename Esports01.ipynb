# %% [markdown]
# <a href="https://colab.research.google.com/github/saktiswarupamallick/Esports-Management-System/blob/main/Esports01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv("GeneralEsportData.csv")

# %%
df2=pd.read_csv("HistoricalEsportData.csv")

# %%
df2.head()
# Out:
#          Date                          Game  Earnings  Players  Tournaments
# 0  1998-01-01  Command & Conquer: Red Alert   15000.0        8            1
# 1  1998-01-01                    QuakeWorld   15000.0        8            1
# 2  1998-05-01                      Quake II   15000.0        4            1
# 3  1998-05-01            Total Annihilation   15000.0        2            1
# 4  1998-05-01                    QuakeWorld     300.0        3            1

# %%
df1.head(3)
# Out:
#                  Game  ReleaseDate     Genre  TotalEarnings  OfflineEarnings  \
# 0      Age of Empires         1997  Strategy      510716.46        375857.63
# 1   Age of Empires II         1999  Strategy     3253232.59       1139384.57
# 2  Age of Empires III         2005  Strategy      115843.65         41800.00
#
#    PercentOffline  TotalPlayers  TotalTournaments
# 0        0.735942           473               265
# 1        0.350232          1994              1613
# 2        0.360831           166               163

# %%
df2.columns
# Out:
# Index(['Date', 'Game', 'Earnings', 'Players', 'Tournaments'], dtype='object')
